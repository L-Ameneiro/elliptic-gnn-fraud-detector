# %%
# Standard library
import os
import random
# Data handling
import pandas as pd
import numpy as np
# PyTorch core
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# PyTorch Geometric
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv, SAGEConv, GATConv
# Graph/network analysis
import networkx as nx
# Scikit-learn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# # Trabajo Práctico n° 3: Entrenamiento de GNNs
# En este trabajo continuamos trabajando con Elliptic Bitcoin Dataset.
#
# En entregas anteriores realizamos análisis exploratorio, análisis de componentes principales y entrenamiento de modelos de aprendizaje automático supervisado para detectar transacciones fraudulentas.
#
# En el presente trabajo entrenaremos Graph Neural Networks para detectar transacciones fraudulentas.

# %% [markdown]
# ### Carga de datos y procesamiento inicial

# %%
# Cargar los archivos
features_csv = pd.read_csv(r"../data/kaggle/elliptic_txs_features.csv", header=None)
edges_csv = pd.read_csv(r"../data/kaggle/elliptic_txs_edgelist.csv")
classes_csv = pd.read_csv(r"../data/kaggle/elliptic_txs_classes.csv")

# Renombrar columnas para claridad
# features = features.rename(columns={0: "txId", 1: "time_step"})
edges_csv = edges_csv.rename(columns={"txId1": "source", "txId2": "target"})
classes_csv = classes_csv.rename(columns={"txId": "txId", "class": "label"})

# %%
# renombrar columnas para mayor claridad
tx_features = ["tx_feat_"+str(i) for i in range(2,95)]
agg_features = ["agg_feat_"+str(i) for i in range(1,73)]
features_csv.columns = ["txId","time_step"] + tx_features + agg_features

# %%
print(f"""Shapes
{4*' '}Features : {features_csv.shape[0]:8,} (rows)  {features_csv.shape[1]:4,} (cols)
{4*' '}Classes  : {classes_csv.shape[0]:8,} (rows)  {classes_csv.shape[1]:4,} (cols)
{4*' '}Edgelist : {edges_csv.shape[0]:8,} (rows)  {edges_csv.shape[1]:4,} (cols)
""")
# Out:
# Shapes
#     Features :  203,769 (rows)   167 (cols)
#     Classes  :  203,769 (rows)     2 (cols)
#     Edgelist :  234,355 (rows)     2 (cols)

# %% [markdown]
# ### Generación de tensors para GNN

# %%
# Crear un mapeo de txId → índice consecutivo (0..N-1)
all_tx_ids = pd.concat([features_csv['txId'], edges_csv["source"], edges_csv["target"]]).unique()
txid_to_idx = {txid: i for i, txid in enumerate(all_tx_ids)}

# %%
# Mapear los edges
source_idx = edges_csv["source"].map(txid_to_idx).values
target_idx = edges_csv["target"].map(txid_to_idx).values

# Construir edge_index tensor [2, num_edges]
edge_index = torch.tensor([source_idx, target_idx], dtype=torch.long)
# Out:
# /tmp/ipykernel_322/586224740.py:6: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   edge_index = torch.tensor([source_idx, target_idx], dtype=torch.long)

# %%
# Features
features_csv = features_csv.set_index('txId')  # 0 = txId
features_csv = features_csv.reindex(all_tx_ids)  # ordenar según txid_to_idx
#X = torch.tensor(features_csv.values, dtype=torch.float32)

# Labels
classes_csv = classes_csv.set_index("txId")
classes_csv = classes_csv.reindex(all_tx_ids)
# Mapear unknown = -1, illicit = 1, licit = 0
#y_np = classes_csv["label"].fillna(0).replace({1:1, 2:0}).values

# mapeamos las etiquetas a los valores deseados
mapping = {"unknown": -1, "1": 1, "2": 0}
classes_csv['label'] = classes_csv['label'].map(mapping)


y = torch.tensor(classes_csv['label'].astype(int).values, dtype=torch.long)

# %% [markdown]
# ### Cálculo de centralidades
# Cálcularemos distintas métricas de centralidad y agregaremos estos datos a las features de cada nodo.
#
# Las métricas de centralidad aportan información sobre la topología global del grafo y local de cada nodo. Estas métricas también permiten diferenciar los nodos, revelando distintos roles dentro de un grafo, como nodos muy conectados, nodos puente, etc.

# %% [markdown]
# Distintas métricas de centralidad y sus interpretaciones:
#
# | Métrica     | Qué mide                                     | Interpretación                               |
# | --------------- | -------------------------------------------- | -------------------------------------------- |
# | **Degree**      | Cantidad de vecinos                          | Nodos muy conectados                         |
# | **Betweenness** | Cuántos caminos más cortos pasan por el nodo | Nodos “puente” entre comunidades             |
# | **Closeness**   | Cercanía promedio a todos los nodos          | Nodos que pueden difundir información rápido |
# | **Eigenvector** | Conexión a nodos importantes                 | Nodos influyentes globalmente                |
#
# De esta lista, no calculamos la de Eigenvector ya que en grafos dirigidos suele no converger a valores estables.

# %%
BETWEENNESS_K = 500   # cantidad de nodos tomados aleatoriamente para aproximar betweenness centrality

# ---------- 4) Calcular centralidades dirigidas (in_deg, out_deg, betweenness aprox, closeness). ----------
# Construimos grafo dirigido en networkx con nodos = txId (usar índices 0..N-1)
G_dir = nx.DiGraph()
G_dir.add_nodes_from(range(len(all_tx_ids)))
G_dir.add_edges_from(list(zip(source_idx.tolist(), target_idx.tolist())))

print("Calculando centralidades dirigidas (puede tardar)...")
# in/out degree centrality (rápido)
in_deg = nx.in_degree_centrality(G_dir)
out_deg = nx.out_degree_centrality(G_dir)

# betweenness aproximada (si el grafo es grande usa k nodos aleatorios)
try:
    if BETWEENNESS_K is not None and BETWEENNESS_K < G_dir.number_of_nodes():
        btw = nx.betweenness_centrality(G_dir, k=min(BETWEENNESS_K, G_dir.number_of_nodes()-1), seed=42)
    else:
        btw = nx.betweenness_centrality(G_dir)
except Exception as e:
    print("Warning: betweenness fallo:", e)
    btw = {n: 0.0 for n in G_dir.nodes()}

# closeness en dirigido (networkx maneja directed)
try:
    clo = nx.closeness_centrality(G_dir)
except Exception as e:
    print("Warning closeness:", e)
    clo = {n: 0.0 for n in G_dir.nodes()}


# convertir a arrays en orden de índices
n_nodes = len(all_tx_ids)
deg_in_arr  = np.array([in_deg.get(i, 0.0) for i in range(n_nodes)], dtype=np.float32).reshape(-1,1)
deg_out_arr = np.array([out_deg.get(i, 0.0) for i in range(n_nodes)], dtype=np.float32).reshape(-1,1)
btw_arr     = np.array([btw.get(i, 0.0) for i in range(n_nodes)], dtype=np.float32).reshape(-1,1)
clo_arr     = np.array([clo.get(i, 0.0) for i in range(n_nodes)], dtype=np.float32).reshape(-1,1)
#eig_arr     = np.array([eig.get(i, 0.0) for i in range(n_nodes)], dtype=np.float32).reshape(-1,1)

centralities = np.hstack([deg_in_arr, deg_out_arr, btw_arr, clo_arr])
print("Centralidades calculadas. shape:", centralities.shape)
# Out:
# Calculando centralidades dirigidas (puede tardar)...
# Centralidades calculadas. shape: (203769, 4)

# %%
# ---------- 5) Features: escoger columnas de features  ----------
feature_cols = features_csv.columns
X_raw = features_csv[feature_cols].values.astype(float)  # numeric features

# concatenar centralities
X_full = np.hstack([X_raw, centralities])

# %% [markdown]
# ### Split estratificado
#
# Partiendo sólo de los nodos etiquetados, usamos máscaras para obtener los subconjuntos de train-test-val.
#
# De esta manera, los nodos "unknown" (-1) quedan fuera del split pero siguen existiendo en el grafo, ya que sirven para la propagación de mensajes en la GNN.
#
# El split estratificado asegura que cada subconjunto contenga una proporción similar de nodos legítimos y fraudulentos.

# %%
# from sklearn.model_selection import train_test_split

# Tomamos solo nodos etiquetados (y >= 0)
labeled_idx = torch.where(y >= 0)[0]
y_labeled = y[labeled_idx].numpy()

# Split train/test (80/20) estratificado por clase
train_idx_rel, test_idx_rel = train_test_split(
    np.arange(len(labeled_idx)),
    test_size=0.2,
    stratify=y_labeled,
    random_state=42
)

train_idx = labeled_idx[train_idx_rel]
test_idx  = labeled_idx[test_idx_rel]

# Split test en val/test (50/50)
val_rel, test_rel, y_val_rel, y_test_rel = train_test_split(
    np.arange(len(test_idx)),
    y_labeled[test_idx_rel],
    test_size=0.5,
    stratify=y_labeled[test_idx_rel],
    random_state=42
)

val_idx = test_idx[val_rel]
test_idx = test_idx[test_rel]

# Crear máscaras booleanas
train_mask = torch.zeros(len(y), dtype=torch.bool)
val_mask   = torch.zeros(len(y), dtype=torch.bool)
test_mask  = torch.zeros(len(y), dtype=torch.bool)

train_mask[train_idx] = True
val_mask[val_idx]     = True
test_mask[test_idx]   = True

# Verificar proporción de clases
def print_class_distribution(y, mask, split_name="Split"):
    labels_split = y[mask].numpy()
    total = len(labels_split)
    fraude = (labels_split == 1).sum()
    legit  = (labels_split == 0).sum()
    print(f"{split_name}: total={total}, fraude={fraude} ({fraude/total*100:.2f}%), legit={legit} ({legit/total*100:.2f}%)")

print_class_distribution(y, train_mask, "Train")
print_class_distribution(y, val_mask, "Val")
print_class_distribution(y, test_mask, "Test")
# Out:
# Train: total=37251, fraude=3636 (9.76%), legit=33615 (90.24%)
# Val: total=4656, fraude=454 (9.75%), legit=4202 (90.25%)
# Test: total=4657, fraude=455 (9.77%), legit=4202 (90.23%)

# %% [markdown]
# ### Escalado de variables
#
# Usamos sólo los datos de entrenamiento para entrenar el escalador, que luego se aplica a los subconjuntos de entrenamiento, testeo y validación.
#
# De esta manera evitamos data leakage de los datos de entrenamiento sobre los otros subconjuntos.

# %%
# escalado
scaler = StandardScaler()
scaler.fit(X_full[train_mask.numpy()])  

X_scaled = scaler.transform(X_full)
X = torch.tensor(X_scaled, dtype=torch.float32)

# %% [markdown]
# ### Definición del tensor global

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


data = Data(
    x=X, 
    y=y, 
    edge_index=edge_index, 
    train_mask=train_mask, 
    val_mask=val_mask, 
    test_mask=test_mask
).to(device)

# %% [markdown]
# ### Entrenamiento de GNNs
# Entrenaremos cinco modelos de GNNs con tres arquitecturas distintas:
#
# - Graph Convolutional Network (GCN)
# - GraphSAGE: Con función de agregación Mean, Sum y Max
# - Graph Attention Network (GAT)
#
# En todos los modelos tendremos en cuenta el desbalanceo entre la clase minoritaria (fraude) y la mayoritaria (legítima).

# %%
# -------------------------------
# 1️⃣ Modelos
# -------------------------------
class GCN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout=0.5):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, hidden_dim)
        self.conv3 = GCNConv(hidden_dim, output_dim)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = F.relu(self.conv2(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index)
        return F.log_softmax(x, dim=1)


class GraphSAGE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, aggr="mean", dropout=0.5):
        super(GraphSAGE, self).__init__()
        self.conv1 = SAGEConv(input_dim, hidden_dim, aggr=aggr)
        self.conv2 = SAGEConv(hidden_dim, hidden_dim, aggr=aggr)
        self.conv3 = SAGEConv(hidden_dim, output_dim, aggr=aggr)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = F.relu(self.conv2(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index)
        return F.log_softmax(x, dim=1)

class GAT(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, heads=4, dropout=0.5):
        super(GAT, self).__init__()
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, dropout=dropout)
        self.conv2 = GATConv(hidden_dim * heads, hidden_dim, heads=heads, dropout=dropout)
        self.conv3 = GATConv(hidden_dim * heads, output_dim, heads=1, concat=False, dropout=dropout)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = F.elu(self.conv2(x, edge_index))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index)
        return F.log_softmax(x, dim=1)


# -------------------------------
# 2️⃣ Funciones de entrenamiento / evaluación
# -------------------------------
def train(model, optimizer, criterion, data):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss.item()

def evaluate(model, data, mask):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)

        y_true = data.y[mask].cpu().numpy()
        y_pred = pred[mask].cpu().numpy()

        acc = (pred[mask] == data.y[mask]).float().mean().item()
        prec = precision_score(y_true, y_pred, zero_division=0)
        rec = recall_score(y_true, y_pred, zero_division=0)
        f1 = f1_score(y_true, y_pred, zero_division=0)

    return acc, prec, rec, f1


# -------------------------------
# 3️⃣ Entrenamiento general
# -------------------------------
def run_experiment(model_class, model_name, data, hidden_dim=64, lr=0.01, epochs=200):
    print(f"\n🚀 Entrenando {model_name}...")

    model = model_class(data.num_features, hidden_dim, 2).to(device)

    # class weights
    classes, counts = torch.unique(data.y[data.train_mask], return_counts=True)
    weights = 1.0 / counts.float()
    weights = weights / weights.sum()
    weights = weights.to(device)

    criterion = nn.CrossEntropyLoss(weight=weights)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=5e-4)

    # training loop
    for epoch in range(epochs):
        loss = train(model, optimizer, criterion, data)
        if epoch % 20 == 0:
            val_acc, val_prec, val_rec, val_f1 = evaluate(model, data, data.val_mask)
            print(f"Epoch {epoch:03d} | Loss: {loss:.4f} | Val Acc: {val_acc:.4f} | Val F1: {val_f1:.4f}")

    # final test
    test_acc, test_prec, test_rec, test_f1 = evaluate(model, data, data.test_mask)
    print(f"\n📊 Resultados {model_name}:")
    print(f"Accuracy:  {test_acc:.4f}")
    print(f"Precision: {test_prec:.4f}")
    print(f"Recall:    {test_rec:.4f}")
    print(f"F1:        {test_f1:.4f}")

# %%
model_gcn = run_experiment(GCN, "GCN", data)
# Out:
# 🚀 Entrenando GCN...
# Epoch 000 | Loss: 3.0521 | Val Acc: 0.9021 | Val F1: 0.0988
# Epoch 020 | Loss: 0.5095 | Val Acc: 0.7216 | Val F1: 0.3933
# Epoch 040 | Loss: 0.3795 | Val Acc: 0.8241 | Val F1: 0.4935
# Epoch 060 | Loss: 0.3329 | Val Acc: 0.8615 | Val F1: 0.5493
# Epoch 080 | Loss: 0.3017 | Val Acc: 0.8769 | Val F1: 0.5839
# Epoch 100 | Loss: 0.2764 | Val Acc: 0.8971 | Val F1: 0.6219
# Epoch 120 | Loss: 0.2455 | Val Acc: 0.9091 | Val F1: 0.6530
# Epoch 140 | Loss: 0.2316 | Val Acc: 0.9070 | Val F1: 0.6488
# Epoch 160 | Loss: 0.2242 | Val Acc: 0.9094 | Val F1: 0.6558
# Epoch 180 | Loss: 0.2178 | Val Acc: 0.9225 | Val F1: 0.6880
#
# 📊 Resultados GCN:
# Accuracy:  0.9132
# Precision: 0.5327
# Recall:    0.9143
# F1:        0.6731

# %%
# GraphSAGE con Mean (default)
model_sage_mean = run_experiment(lambda in_dim, hidden, out: GraphSAGE(in_dim, hidden, out, aggr="mean"),
                                 "GraphSAGE-Mean", data)

# GraphSAGE con Sum
model_sage_sum = run_experiment(lambda in_dim, hidden, out: GraphSAGE(in_dim, hidden, out, aggr="sum"),
                                "GraphSAGE-Sum", data)

# GraphSAGE con Max
model_sage_max = run_experiment(lambda in_dim, hidden, out: GraphSAGE(in_dim, hidden, out, aggr="max"),
                                "GraphSAGE-Max", data)
# Out:
# 🚀 Entrenando GraphSAGE-Mean...
# Epoch 000 | Loss: 1.0036 | Val Acc: 0.9010 | Val F1: 0.0043
# Epoch 020 | Loss: 0.3019 | Val Acc: 0.8681 | Val F1: 0.5718
# Epoch 040 | Loss: 0.2012 | Val Acc: 0.9373 | Val F1: 0.7331
# Epoch 060 | Loss: 0.1527 | Val Acc: 0.9560 | Val F1: 0.7984
# Epoch 080 | Loss: 0.1294 | Val Acc: 0.9613 | Val F1: 0.8189
# Epoch 100 | Loss: 0.1140 | Val Acc: 0.9609 | Val F1: 0.8173
# Epoch 120 | Loss: 0.1060 | Val Acc: 0.9568 | Val F1: 0.8058
# Epoch 140 | Loss: 0.1043 | Val Acc: 0.9609 | Val F1: 0.8180
# Epoch 160 | Loss: 0.0934 | Val Acc: 0.9656 | Val F1: 0.8367
# Epoch 180 | Loss: 0.0934 | Val Acc: 0.9665 | Val F1: 0.8402
#
# 📊 Resultados GraphSAGE-Mean:
# Accuracy:  0.9697
# Precision: 0.8008
# Recall:    0.9187
# F1:        0.8557
#
# 🚀 Entrenando GraphSAGE-Sum...
# Epoch 000 | Loss: 2.2552 | Val Acc: 0.8546 | Val F1: 0.1734
# Epoch 020 | Loss: 0.4881 | Val Acc: 0.7545 | Val F1: 0.4219
# Epoch 040 | Loss: 0.2976 | Val Acc: 0.8634 | Val F1: 0.5679
# ...

# %%
model_gat = run_experiment(GAT, "GAT", data)
# Out:
# 🚀 Entrenando GAT...
# Epoch 000 | Loss: 8.8424 | Val Acc: 0.7446 | Val F1: 0.3147
# Epoch 020 | Loss: 0.7226 | Val Acc: 0.5131 | Val F1: 0.2837
# Epoch 040 | Loss: 0.5762 | Val Acc: 0.5468 | Val F1: 0.2981
# Epoch 060 | Loss: 0.5060 | Val Acc: 0.6155 | Val F1: 0.3336
# Epoch 080 | Loss: 0.4868 | Val Acc: 0.6641 | Val F1: 0.3642
# Epoch 100 | Loss: 0.4736 | Val Acc: 0.6725 | Val F1: 0.3691
# Epoch 120 | Loss: 0.4649 | Val Acc: 0.6982 | Val F1: 0.3851
# Epoch 140 | Loss: 0.4590 | Val Acc: 0.7483 | Val F1: 0.4272
# Epoch 160 | Loss: 0.4459 | Val Acc: 0.7491 | Val F1: 0.4291
# Epoch 180 | Loss: 0.4502 | Val Acc: 0.7766 | Val F1: 0.4566
#
# 📊 Resultados GAT:
# Accuracy:  0.7934
# Precision: 0.3191
# Recall:    0.9824
# F1:        0.4817

# %% [markdown]
# ## Comparación y discusión

# %% [markdown]
# Nuestro objetivo es detectar la mayor cantidad posible de transacciones fraudulentas con la menor cantidad posible de falsos positivos. En otras palabras, buscamos un balance entre Precision y Recall, por lo que buscaremos maximizar el F1.
#
# De todos los modelos de GNNs entrenadas, el que obtuvo el mayor F1 es GraphSAGE-Sum. Este modelo detecta casi el 91% de las transacciones fraudulentas del subconjunto de test. De las transacciones que señala como fraudulentas, el 75% son efectivamente fraudulentas.
#
# Sin embargo, estas métricas muestran un desempeño peor que el mejor modelo de aprendizaje supervisado clásico (Random Forest) que entrenamos en la entrega anterior, incluido en la siguiente tabla como RF_3.
#
# | Modelo           | Accuracy | Precision | Recall  | F1-score |
# |-----------------|---------|-----------|---------|----------|
# | GCN             | 0.9132  | 0.5327    | 0.9143  | 0.6731   |
# | GraphSAGE-Mean  | 0.9697  | 0.8008    | 0.9187  | 0.8557   |
# | GraphSAGE-Sum   | 0.9611  | 0.7473    | 0.9099  | 0.8206   |
# | GraphSAGE-Max   | 0.9682  | 0.7902    | 0.9187  | 0.8496   |
# | GAT             | 0.7934  | 0.3191    | 0.9824  | 0.4817   |
# | RF_3             | 0.9864  | 0.9958    | 0.8754  | 0.9317   |
#
# Dado que ya tuvimos en cuenta el desbalanceo de clases y agregamos métricas estructurales del grafo, quedan algunos caminos posibles para mejorar el rendimiento de las GNNs:
#
# - Aumentar la profundidad de la red (actualmente 2 capas)
#
# - Incrementar la dimensión del embedding (`hidden_dim`, actualmente 64). En tal caso debemos chequear que no haya sobreajuste.
#
# - Ajustar dropout (0.2–0.5) ayuda a reducir sobreajuste.
#
# - Modificar el learning rate.
